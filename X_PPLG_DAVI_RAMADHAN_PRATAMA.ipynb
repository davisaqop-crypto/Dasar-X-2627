# %% [markdown]
# <a href="https://colab.research.google.com/github/davisaqop-crypto/Dasar-X-2627/blob/main/X_PPLG_DAVI_RAMADHAN_PRATAMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tugas 1 praktik tipe data dan variabel
#
# Nama kelompok: NEXACODE
# nama anggota:
# 1. Davi Ramadhan Pratama
# 2. Aghnan aiszar Kamaludin
# 3. Teuku Muhammad Fadhil
# 4. Raisya putri darmawan
# 5. Alyaa Rahma Thalita
# 6. Syafira meidina Syarif
# 7. Nur mawadah

# %%
# %%writefile praktik_variabel.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     // Deklarasi Variabel dan Tipe Data
#     string namaBarang = "Sepatu Adidas";
#     int jumlah = 40;
#     float harga = 2900000.50;
#     char kategori = 'C';
#     bool tersedia = true;
#
#     // Menampilkan Output ke Layar
#     cout << "=== DATA INVENTARIS ===" << endl;
#     cout << "Nama Barang : " << namaBarang << endl;
#     cout << "Kategori    : " << kategori << endl;
#     cout << "Jumlah      : " << jumlah << endl;
#     cout << "Harga       : Rp " << harga << endl;
#     cout << "Tersedia    : " << tersedia << " (1 = Ya, 0 = Tidak)" << endl;
#     cout << "=======================" << endl;
#
#     return 0;
# }
# Out:
# Overwriting praktik_variabel.cpp

# %%
# !g++ praktik_variabel.cpp -o praktik_variabel

# %%
# !./praktik_variabel
# Out:
# === DATA INVENTARIS ===
# Nama Barang : Sepatu Adidas
# Kategori    : C
# Jumlah      : 40
# Harga       : Rp 2.9e+06
# Tersedia    : 1 (1 = Ya, 0 = Tidak)
# ...
