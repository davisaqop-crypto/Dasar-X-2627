# %% [markdown]
# <a href="https://colab.research.google.com/github/davisaqop-crypto/Dasar-X-2627/blob/main/Tugas_program_menghitung_persegi_panjang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS MEMBUAT MENGHITUNG LUAS PERSEGI PANJANG
# NAMA KELOMPOK : NEXACODE
# 1. FADHIL
# 2. AGHNA
# 3. DAVI
# 4. DINA
# 5. ALYA
# 6. NURMA
# 7. RAISYA

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile luaspersegipanjang.cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#     float panjang, lebar, luas;
#
#     cout << "masukan panjang: ";
#     cin >> panjang;
#     cout << "masukan lebar: ";
#     cin >> lebar;
#
#     luas = panjang * lebar;
#     cout << "luas persegi panjang = " << luas << endl;
#
#     return 0;
# }
# Out:
# Writing luaspersegipanjang.cpp

# %%
# !g++ ./luaspersegipanjang.cpp -o main

# %%
! ./main
# Out:
# masukan panjang: 8
# masukan lebar: 9
# luas persegi panjang = 72
